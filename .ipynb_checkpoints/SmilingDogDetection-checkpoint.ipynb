# %% [markdown]
# ## Dataset preparation from online

# %%
from google_images_download import google_images_download

# %%
response = google_images_download.googleimagesdownload()
search_queries = ['smiling dogs','sad dogs']
## add smiling person as label 0

# %%
# m_smiling_dog = 1000
# m_smiling_person = 600
# m_sad_dog = 600
def downloadimages(query):
    arguments = dict(keywords=query,
                    limit=20,
                    #format='jpg',
                    #aspect_ratio='wide',
                    #size='medium',
                    silent_mode=True)
    try: 
        response.download(arguments)     
    except FileNotFoundError:  
        arguments = dict(keywords=query,
                    limit=20,
                    print_urls=True)                       
        try:  
            response.download(arguments)  
        except: 
            pass

# %%
for query in search_queries: 
    downloadimages(query)
# Out:
# Item no.: 1 --> Item name = smiling dogs
# Evaluating...
# Starting Download...
# Image URL: https://i.ytimg.com/vi/8XKmAkF8C-U/maxresdefault.jpg
# Completed Image ====> 1.maxresdefault.jpg
# Image URL: https://www.petmd.com/sites/default/files/CANS_dogsmiling_379727605.jpg
# Completed Image ====> 2.CANS_dogsmiling_379727605.jpg
# Image URL: https://i.ytimg.com/vi/01Pe3IkBHvw/hqdefault.jpg
# Completed Image ====> 3.hqdefault.jpg
# Image URL: https://i.ytimg.com/vi/Lrp2r91Z78w/maxresdefault.jpg
# Completed Image ====> 4.maxresdefault.jpg
# Image URL: https://barkpost-assets.s3.amazonaws.com/wp-content/uploads/2013/10/1.jpg
# Completed Image ====> 5.1.jpg
# Image URL: https://i.ytimg.com/vi/erEfPcA7M7E/maxresdefault.jpg
# Completed Image ====> 6.maxresdefault.jpg
# Image URL: https://thebark.com/sites/default/files/styles/full/public/content/blog/full/81c39033-68b8-4096-8f29-a73ef7df2ac5.jpg?itok=jrtNNT6o
# Completed Image ====> 7.81c39033-68b8-4096-8f29-a73ef7df2ac5.jpg
# Image URL: https://i.pinimg.com/236x/e1/09/d1/e109d19d4cff44c8706046b6c69d3e78--smiling-dogs-smiling-animals.jpg
# Completed Image ====> 8.e109d19d4cff44c8706046b6c69d3e78--smiling-dogs-smiling-animals.jpg
# Image URL: https://static.boredpanda.com/blog/wp-content/uploads/2015/09/happy-dogs-smiling-fb__700.jpg
# Completed Image ====> 9.happy-dogs-smiling-fb__700.jpg
# Image URL: https://www.thisdogslife.co/wp-content/uploads/2019/02/dog-grasshopper.png
# Completed Image ====> 10.dog-grasshopper.png
# Image URL: https://barkpost-assets.s3.amazonaws.com/wp-content/uploads/2013/10/51.jpg
# Completed Image ====> 11.51.jpg
# Image URL: https://static.boredpanda.com/blog/wp-content/uploads/2015/09/post-the-happiest-dogs-who-show-the-best-smiles-18__700.jpg
# Completed Image ====> 12.post-the-happiest-dogs-who-show-the-best-smiles-18__700.jpg
# Image URL: https://i.pinimg.com/originals/82/46/8e/82468ee6b3b0d83a43090862fea468ae.jpg
# Completed Image ====> 13.82468ee6b3b0d83a43090862fea468ae.jpg
# Image URL: https://assets3.thrillist.com/v1/image/2547068/size/tmg-article_tall;jpeg_quality=20.jpg
://hips.hearstapps.com/hmg-prod.s3.amazonaws.com/images/sad-dog-1537347496.jpg
# Completed Image ====> 9.sad-dog-1537347496.jpg
# Image URL: https://i.ytimg.com/vi/bRPoptQARs4/maxresdefault.jpg
# Completed Image ====> 10.maxresdefault.jpg
# Image URL: https://petcube.com/blog/content/images/2018/12/sad-dog-in-the-bed.jpg
# Completed Image ====> 11.sad-dog-in-the-bed.jpg
# Image URL: https://www.dogingtonpost.com/wp-content/uploads/2014/12/SADisorder_opt.jpg
# Completed Image ====> 12.SADisorder_opt.jpg
# Image URL: https://i.imgur.com/b4yyOHw.jpg
# Completed Image ====> 13.b4yyOHw.jpg
# Image URL: https://barkingroyalty.com/wp-content/uploads/2016/09/Can-Dogs-Cry-Tears.jpg
# Completed Image ====> 14.Can-Dogs-Cry-Tears.jpg
# Image URL: http://www.pethealthnetwork.com/sites/default/files/eight-tips-for-coping-with-your-dogs-age-related-hearing-loss-1-490479620.jpg
# Completed Image ====> 15.eight-tips-for-coping-with-your-dogs-age-related-hearing-loss-1-490479620.jpg
# Image URL: http://foreverhomewanted.com/wp-content/uploads/2017/06/word-image-5.png
# Completed Image ====> 16.word-image-5.png
# Image URL: https://images.wagwalkingweb.com/media/articles/dog/why-is-my-dog-acting-sad/why-is-my-dog-acting-sad.jpg
# Completed Image ====> 17.why-is-my-dog-acting-sad.jpg
# Image URL: https://i.ytimg.com/vi/2NzRvK8vh_Y/maxresdefault.jpg
# Completed Image ====> 18.maxresdefault.jpg
# Image URL: https://static.boredpanda.com/blog/wp-content/uploads/2017/05/saddest-dog-homeless-again-lana-4-5914527ccabca__700.jpg
# Completed Image ====> 19.saddest-dog-homeless-again-lana-4-5914527ccabca__700.jpg
# Image URL: https://www.dogster.com/wp-content/uploads/2017/11/A-dog-behind-a-fence-or-in-a-cage.jpg
# Completed Image ====> 20.A-dog-behind-a-fence-or-in-a-cage.jpg
#
# Errors: 1

# %% [markdown]
# ## File renaming

# %%
import os
original_path = os.getcwd()
data_path = os.path.join(original_path,'downloads')
data_folders = os.listdir(data_path)

# %%
for folder in data_folders:
    working_dir = os.path.join(data_path,folder)
    os.chdir(working_dir)
    current_list = os.listdir(os.getcwd())
    for i in range(len(os.listdir(working_dir))):
        original_name = current_list[i]
        new_name = "".join(folder.split()) + '_{:04d}'.format(i+1) + os.path.splitext(original_name)[-1]
        if not os.path.exists(new_name):
            os.rename(original_name,new_name)
os.chdir(original_path)

# %% [markdown]
# ## display

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
np.random.seed(seed=0)
n_samples = 5
fig, row = plt.subplots(2, n_samples, figsize = (4*n_samples, 3*2))

for col,folder in zip(row,data_folders):
    col[int(np.floor(n_samples/2))].set_title(folder,fontsize=25)
    working_dir = os.path.join(data_path,folder)
    os.chdir(working_dir)
    for col_ax,img in zip(col,np.random.choice(os.listdir(os.getcwd()),n_samples,replace=False)):
        rand_img = cv2.imread(img)
        rand_img = cv2.cvtColor(rand_img,cv2.COLOR_BGR2RGB)
        col_ax.imshow(rand_img)
        col_ax.axis('off')
plt.subplots_adjust(left=0.2, wspace=0.02)
os.chdir(original_path)

# %% [markdown]
# ## Load and pre-processing

# %%
img_rows = 128
img_cols = 128
img_list = []
label_list = []
labels = dict([('sad dogs',0),('smiling dogs',1)])
for folder in data_folders:
    working_dir = os.path.join(data_path,folder)
    os.chdir(working_dir)
    current_list = os.listdir(os.getcwd())
    for img in current_list:
        img_in = cv2.imread(img)
        img_in = cv2.cvtColor(img_in,cv2.COLOR_BGR2GRAY)
        img_in = cv2.resize(img_in,(img_rows,img_cols))
        img_list.append(img_in)
        label_list.append(labels[folder])
os.chdir(original_path)

# %% [markdown]
# #### normalization

# %%
img_data = np.array(img_list).astype('float32')
img_label = np.array(label_list)
img_data /= 255
img_data = np.expand_dims(img_data,axis=3)

# %%
print(img_data.shape) #(m,row,col,channel)
print(img_label.shape)
# Out:
# (40, 128, 128, 1)
# (40,)

# %% [markdown]
# ## Splitting

# %%
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle
X_shuffled, y_shuffled = shuffle(img_data,label_list,random_state=0)

X_train,X_valid_test,y_train,y_valid_test = train_test_split(X_shuffled,y_shuffled,test_size=0.1,random_state=0,stratify=y_shuffled)
X_dev,X_test,y_dev,y_test = train_test_split(X_valid_test,y_valid_test,test_size=0.5,random_state=0,stratify=y_valid_test)
print('X_train shape: {}'.format(X_train.shape))
print('y_train shape: {}'.format(y_train.shape))
print('X_valid shape: {}'.format(X_dev.shape))
print('y_valid shape: {}'.format(y_dev.shape))
print('X_test shape: {}'.format(X_test.shape))
print('y_test shape: {}'.format(y_test.shape))
# Out:
# X_train shape: (36, 128, 128, 1)
# y_train shape: (36,)
# X_valid shape: (2, 128, 128, 1)
# y_valid shape: (2,)
# X_test shape: (2, 128, 128, 1)
# y_test shape: (2,)

# %% [markdown]
# ## Model building

# %%
from keras.models import Sequential
from keras.layers import Dense,Activation,BatchNormalization,Flatten,Conv2D,MaxPooling2D,ZeroPadding2D,GlobalAveragePooling2D,Dropout
from keras.callbacks import ModelCheckpoint,ReduceLROnPlateau
from keras.optimizers import Adam,RMSprop
#from keras.preprocessing.image import ImageDataGenerator
#from keras.applications.vgg16 import VGG16
#from keras import backend as K
#from keras.models import load_model

# %%
optimizer = Adam(lr=0.0005, beta_1=0.9, beta_2=0.999, epsilon=10**-8, amsgrad=False)
epochs = 100
batch_size = 32

# %%
X_input_shape = img_data[0].shape

# X1 = Conv2D(16, (3, 3), strides = (1, 1),padding='same')(X_input_shape)

model = Sequential([
    Conv2D(32,(3,3),padding='same',input_shape=X_input_shape),
    Activation('relu'),
    Conv2D(64,(3,3),padding='same',input_shape=X_input_shape),
    Activation('relu'),
    MaxPooling2D((2,2)),
    Dropout(0.5),
    
    Flatten(),
    Dense(128),
    Activation('relu'),
    Dropout(0.5),
    Dense(1),
    Activation('sigmoid')
])
model.compile(optimizer=optimizer,loss='binary_crossentropy',metrics=['accuracy'])

# %%
# hist_1 = model_1.fit(X_train,y_train,epochs=epochs,batch_size=batch_size,verbose=1,validation_data=(X_dev,y_dev),callbacks=[save_best_model_1,learning_rate_reduction])

# %% [markdown]
# ## make the notebook using image generator
